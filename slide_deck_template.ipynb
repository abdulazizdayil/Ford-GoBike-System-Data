# %% [markdown]
# # (Ford GoBike System Data)
# ## by (Abdulaziz Omar Bin Dayil)

# %% [markdown]
# ## Investigation Overview
#
# > in this investigation, i wanted to show you the relationship between the data that i selected.
#
# ## Dataset Overview
#
# > The data is Ford GoBike System Data and its about the cycling station and the time that the coustemer took the bike and the names of the staions etc.

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# %%
# load in the dataset into a pandas dataframe
df=pd.read_csv("201902-fordgobike-tripdata.csv")

# %% [markdown]
# ## (The Rider Birth Year)
#
# > Like we see most of the riders are between 40 and 25 years old

# %%
bin_edges = np.arange(df['member_birth_year'].min(), df['member_birth_year'].max() + 1, 1)
plt.hist(data = df, x ='member_birth_year',bins = bin_edges);
plt.title('The Rider Birth Year');
plt.xlabel('Year of Birth');
plt.ylabel('Counts');

# %% [markdown]
# ## (Number of customer users and subsrciber users)
#
# > the the number of subscribers is more than the customer

# %%
sb.countplot(data = df, x = 'user_type');
plt.xlabel('User Type');
plt.title('Number of customer users and subsrciber users');

# %% [markdown]
# ## (The Most The Rider Gender)
#
# > Most of the riders are men and we can say that this sport is more popular for men

# %%
base_color = sb.color_palette()[2]
sb.countplot(data = df, x = 'member_gender');
plt.title('The Rider Gender');
plt.xlabel('Gender of Rider');

# %% [markdown]
# ## (The Rider Type and Duration in Seconds)
#
# > The Coustomers takes more time than the Subscribers

# %%
sb.violinplot(data = df.query('duration_sec <= 838 + 1.5*474'),
              x = 'user_type',y='duration_sec');
plt.title('The Rider Type and Duration in Seconds');
plt.xlabel('User Type');
plt.ylabel('Duration in Seconds');

# %% [markdown]
# ## (Year of Birth)
#
# - Customer usually takes from 500 to 1000 Seconds in thier Rides
# - Subscriber usually takes from 0 to 500 Seconds in thier Rides
# - and they are all between 1980 and 1995 Years old

# %%
x_bin = np.arange( df['member_birth_year'].min(), df['member_birth_year'].max()+5, 5)
y_bin = np.arange(0, (838 + 1.5*474)+500, 500)
_temp = df.sample(35000, random_state=42)
m = sb.FacetGrid(data = _temp, col = 'user_type',height=5.4)
m.map(plt.hist2d, 'member_birth_year','duration_sec',cmin=0.5,cmap = 'viridis_r',bins=[x_bin, y_bin]);
plt.ylim((0,(838 + 1.5*474)));
plt.colorbar();
plt.xlabel('Year of Birth');
plt.ylabel('Duration in Seconds');

# %%
pip install nbconvert
# Out:
# Requirement already satisfied: nbconvert in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (6.0.7)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (from nbconvert) (0.5.1)
# Requirement already satisfied: jinja2>=2.4 in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (from nbconvert) (2.11.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (from nbconvert) (0.8.4)
# Requirement already satisfied: nbformat>=4.4 in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (from nbconvert) (5.1.3)
# Requirement already satisfied: jupyterlab-pygments in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (from nbconvert) (0.1.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (from nbconvert) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (from nbconvert) (1.4.3)
# Requirement already satisfied: testpath in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (from nbconvert) (0.4.4)
# Requirement already satisfied: defusedxml in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (from nbconvert) (0.7.1)
# Requirement already satisfied: traitlets>=4.2 in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (from nbconvert) (5.0.5)
# Requirement already satisfied: jupyter-core in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (from nbconvert) (4.7.1)
# Requirement already satisfied: bleach in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (from nbconvert) (3.3.0)
# Requirement already satisfied: pygments>=2.4.1 in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (from nbconvert) (2.9.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (from jinja2>=2.4->nbconvert) (2.0.1)
# Requirement already satisfied: async-generator in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert) (1.10)
# Requirement already satisfied: jupyter-client>=6.1.5 in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert) (6.1.12)
# Requirement already satisfied: nest-asyncio in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert) (2.8.1)
# Requirement already satisfied: tornado>=4.1 in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert) (6.1)
# Requirement already satisfied: pyzmq>=13 in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert) (20.0.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (from nbformat>=4.4->nbconvert) (3.2.0)
# Requirement already satisfied: ipython-genutils in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (from nbformat>=4.4->nbconvert) (0.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert) (21.2.0)
# Requirement already satisfied: setuptools in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert) (52.0.0.post20210125)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert) (0.17.3)
# Requirement already satisfied: six>=1.11.0 in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert) (1.15.0)
# Requirement already satisfied: packaging in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert) (20.9)
# Requirement already satisfied: webencodings in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages (from packaging->bleach->nbconvert) (2.4.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !jupyter nbconvert slide_deck_template.ipynb --to slides --no-input --no-prompt
# Out:
# [NbConvertApp] WARNING | Config option `kernel_spec_manager_class` not recognized by `NbConvertApp`.
# [NbConvertApp] Converting notebook slide_deck_template.ipynb to slides
# [NbConvertApp] Writing 667777 bytes to slide_deck_template.slides.html
